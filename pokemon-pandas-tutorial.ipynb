# %% [markdown]
# <a href="https://www.kaggle.com/code/seanhatch/pokemon-pandas-tutorial?scriptVersionId=194736786" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Practicing Using Pandas with Pokemon Dataset
#
# ![Pancham](https://assets.pokemon.com/assets/cms2/img/pokedex/full//674.png)

# %%
# Importing packages and dataset

import pandas as pd
import re

df = pd.read_csv('/kaggle/input/pokemon-data-for-pandas-tutorial/pokemon_data.csv')

df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
# Read headers

df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
# Read one column

df['Name']
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
# Reading multiple columns -- note the double []

df[['Name', 'Type 1', 'HP']]
# Out:
#                       Name   Type 1  HP
# 0                Bulbasaur    Grass  45
# 1                  Ivysaur    Grass  60
# 2                 Venusaur    Grass  80
# 3    VenusaurMega Venusaur    Grass  80
# 4               Charmander     Fire  39
# ..                     ...      ...  ..
# 795                Diancie     Rock  50
# 796    DiancieMega Diancie     Rock  50
# 797    HoopaHoopa Confined  Psychic  80
# 798     HoopaHoopa Unbound  Psychic  80
# 799              Volcanion     Fire  80
#
# [800 rows x 3 columns]

# %%
# Read a row with integer location

df.iloc[1]
# Out:
# #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object

# %%
# Read several rows using integer location -- not inclusive of end of range

df.iloc[0:3]
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %%
# Read a specifc location with integer location

df.iloc[2,1]
# Out:
# 'Venusaur'

# %%
# Read row with location

df.loc[df['Name'] == 'Pikachu']
# Out:
#      #     Name    Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 30  25  Pikachu  Electric    NaN  35      55       40       50       50
#
#     Speed  Generation  Legendary
# 30     90           1      False

# %%
# Read multiple rows based on condition using location

df.loc[df['Type 1'] == 'Electric']
# Out:
#        #                      Name    Type 1  Type 2  HP  Attack  Defense  \
# 30    25                   Pikachu  Electric     NaN  35      55       40
# 31    26                    Raichu  Electric     NaN  60      90       55
# 88    81                 Magnemite  Electric   Steel  25      35       70
# 89    82                  Magneton  Electric   Steel  50      60       95
# 108  100                   Voltorb  Electric     NaN  40      30       50
# 109  101                 Electrode  Electric     NaN  60      50       70
# 134  125                Electabuzz  Electric     NaN  65      83       57
# 146  135                   Jolteon  Electric     NaN  65      65       60
# 157  145                    Zapdos  Electric  Flying  90      90       85
# 186  172                     Pichu  Electric     NaN  20      40       15
# 193  179                    Mareep  Electric     NaN  55      40       40
# 194  180                   Flaaffy  Electric     NaN  70      55       55
# 195  181                  Ampharos  Electric     NaN  90      75       85
# 196  181     AmpharosMega Ampharos  Electric  Dragon  90      95      105
# 258  239                    Elekid  Electric     NaN  45      63       37
# 262  243                    Raikou  Electric     NaN  90      85       75
# 337  309                 Electrike  Electric     NaN  40      45       40
# 338  310                 Manectric  Electric     NaN  70      75       60
# 339  310   ManectricMega Manectric  Electric     NaN  70      75       80
# 340  311                    Plusle  Electric     NaN  60      50       40
# 341  312                     Minun  Electric     NaN  60      40       50
# 448  403                     Shinx  Electric     NaN  45      65       34
# 449  404                     Luxio  Electric     NaN  60      85       49
# 450  405                    Luxray  Electric     NaN  80     120       79
# 464  417                 Pachirisu  Electric     NaN  60      45       70
# 513  462                 Magnezone  Electric   Steel  70      70      115
# 517  466                Electivire  Electric     NaN  75     123       67
# 531  479                     Rotom  Electric   Ghost  50      50       77
# 532  479           RotomHeat Rotom  Electric    Fire  50      65      107
# 533  479           RotomWash Rotom  Electric   Water  50      65      107
# 534  479          RotomFrost Rotom  Electric     Ice  50      65      107
# 535  479            RotomFan Rotom  Electric  Flying  50      65      107
# 536  479            RotomMow Rotom  Electric   Grass  50      65      107
# 581  522                   Blitzle  Electric     NaN  45      60       32
# 582  523                 Zebstrika  Electric     NaN  75     100       63
# 648  587                    Emolga  Electric  Flying  55      75       60
# 663  602                    Tynamo  Electric     NaN  35      55       40
# 664  603                 Eelektrik  Electric     NaN  65      85       70
# 665  604                Eelektross  Electric     NaN  85     115       80
# 704  642  ThundurusIncarnate Forme  Electric  Flying  79     115       70
# 705  642    ThundurusTherian Forme  Electric  Flying  79     105       70
# 764  694                Helioptile  Electric  Normal  44      38       33
# 765  695                 Heliolisk  Electric  Normal  62      55       52
# 772  702                   Dedenne  Electric   Fairy  67      58       57
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 30        50       50     90           1      False
# 31        90       80    110           1      False
# 88        95       55     45           1      False
# 89       120       70     70           1      False
# 108       55       55    100           1      False
# 109       80       80    140           1      False
# 134       95       85    105           1      False
# 146      110       95    130           1      False
# 157      125       90    100           1       True
# 186       35       35     60           2      False
# 193       65       45     35           2      False
# 194       80       60     45           2      False
# 195      115       90     55           2      False
# 196      165      110     45           2      False
# 258       65       55     95           2      False
# 262      115      100    115           2       True
# 337       65       40     65           3      False
# 338      105       60    105           3      False
# 339      135       80    135           3      False
# 340       85       75     95           3      False
# 341       75       85     95           3      False
# 448       40       34     45           4      False
# 449       60       49     60           4      False
# 450       95       79     70           4      False
# 464       45       90     95           4      False
# 513      130       90     60           4      False
# 517       95       85     95           4      False
# 531       95       77     91           4      False
# 532      105      107     86           4      False
# 533      105      107     86           4      False
# 534      105      107     86           4      False
# 535      105      107     86           4      False
# 536      105      107     86           4      False
# 581       50       32     76           5      False
# 582       80       63    116           5      False
# 648       75       60    103           5      False
# 663       45       40     60           5      False
# 664       75       70     40           5      False
# 665      105       80     50           5      False
# 704      125       80    111           5       True
# 705      145       80    101           5       True
# 764       61       43     70           6      False
# 765      109       94    109           6      False
# 772       81       67    101           6      False

# %%
# Read multiple rows based on OR condition using location

df.loc[(df['Type 1'] == 'Electric') | (df['Type 2'] == 'Electric')]
# Out:
#        #                      Name    Type 1    Type 2   HP  Attack  Defense  \
# 30    25                   Pikachu  Electric       NaN   35      55       40
# 31    26                    Raichu  Electric       NaN   60      90       55
# 88    81                 Magnemite  Electric     Steel   25      35       70
# 89    82                  Magneton  Electric     Steel   50      60       95
# 108  100                   Voltorb  Electric       NaN   40      30       50
# 109  101                 Electrode  Electric       NaN   60      50       70
# 134  125                Electabuzz  Electric       NaN   65      83       57
# 146  135                   Jolteon  Electric       NaN   65      65       60
# 157  145                    Zapdos  Electric    Flying   90      90       85
# 184  170                  Chinchou     Water  Electric   75      38       38
# 185  171                   Lanturn     Water  Electric  125      58       58
# 186  172                     Pichu  Electric       NaN   20      40       15
# 193  179                    Mareep  Electric       NaN   55      40       40
# 194  180                   Flaaffy  Electric       NaN   70      55       55
# 195  181                  Ampharos  Electric       NaN   90      75       85
# 196  181     AmpharosMega Ampharos  Electric    Dragon   90      95      105
# 258  239                    Elekid  Electric       NaN   45      63       37
# 262  243                    Raikou  Electric       NaN   90      85       75
# 337  309                 Electrike  Electric       NaN   40      45       40
# 338  310                 Manectric  Electric       NaN   70      75       60
# 339  310   ManectricMega Manectric  Electric       NaN   70      75       80
# 340  311                    Plusle  Electric       NaN   60      50       40
# 341  312                     Minun  Electric       NaN   60      40       50
# 448  403                     Shinx  Electric       NaN   45      65       34
# 449  404                     Luxio  Electric       NaN   60      85       49
# 450  405                    Luxray  Electric       NaN   80     120       79
# 464  417                 Pachirisu  Electric       NaN   60      45       70
# 513  462                 Magnezone  Electric     Steel   70      70      115
# 517  466                Electivire  Electric       NaN   75     123       67
# 531  479                     Rotom  Electric     Ghost   50      50       77
# 532  479           RotomHeat Rotom  Electric      Fire   50      65      107
# 533  479           RotomWash Rotom  Electric     Water   50      65      107
# 534  479          RotomFrost Rotom  Electric       Ice   50      65      107
# 535  479            RotomFan Rotom  Electric    Flying   50      65      107
# 536  479            RotomMow Rotom  Electric     Grass   50      65      107
# 581  522                   Blitzle  Electric       NaN   45      60       32
# 582  523                 Zebstrika  Electric       NaN   75     100       63
# 648  587                    Emolga  Electric    Flying   55      75       60
# 656  595                    Joltik       Bug  Electric   50      47       50
# 657  596                Galvantula       Bug  Electric   70      77       60
# 663  602                    Tynamo  Electric       NaN   35      55       40
# 664  603                 Eelektrik  Electric       NaN   65      85       70
# 665  604                Eelektross  Electric       NaN   85     115       80
# 679  618                  Stunfisk    Ground  Electric  109      66       84
# 704  642  ThundurusIncarnate Forme  Electric    Flying   79     115       70
# 705  642    ThundurusTherian Forme  Electric    Flying   79     105       70
# 707  644                    Zekrom    Dragon  Electric  100     150      120
# 764  694                Helioptile  Electric    Normal   44      38       33
# 765  695                 Heliolisk  Electric    Normal   62      55       52
# 772  702                   Dedenne  Electric     Fairy   67      58       57
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 30        50       50     90           1      False
# 31        90       80    110           1      False
# 88        95       55     45           1      False
# 89       120       70     70           1      False
# 108       55       55    100           1      False
# 109       80       80    140           1      False
# 134       95       85    105           1      False
# 146      110       95    130           1      False
# 157      125       90    100           1       True
# 184       56       56     67           2      False
# 185       76       76     67           2      False
# 186       35       35     60           2      False
# 193       65       45     35           2      False
# 194       80       60     45           2      False
# 195      115       90     55           2      False
# 196      165      110     45           2      False
# 258       65       55     95           2      False
# 262      115      100    115           2       True
# 337       65       40     65           3      False
# 338      105       60    105           3      False
# 339      135       80    135           3      False
# 340       85       75     95           3      False
# 341       75       85     95           3      False
# 448       40       34     45           4      False
# 449       60       49     60           4      False
# 450       95       79     70           4      False
# 464       45       90     95           4      False
# 513      130       90     60           4      False
# 517       95       85     95           4      False
# 531       95       77     91           4      False
# 532      105      107     86           4      False
# 533      105      107     86           4      False
# 534      105      107     86           4      False
# 535      105      107     86           4      False
# 536      105      107     86           4      False
# 581       50       32     76           5      False
# 582       80       63    116           5      False
# 648       75       60    103           5      False
# 656       57       50     65           5      False
# 657       97       60    108           5      False
# 663       45       40     60           5      False
# 664       75       70     40           5      False
# 665      105       80     50           5      False
# 679       81       99     32           5      False
# 704      125       80    111           5       True
# 705      145       80    101           5       True
# 707      120      100     90           5       True
# 764       61       43     70           6      False
# 765      109       94    109           6      False
# 772       81       67    101           6      False

# %%
# See numerical data descriptions

df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# max    180.000000     6.00000

# %%
# Sorting values alphabetically by name

df.sort_values('Name')
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 510       92       85     60           4      False
# 511      132      105     30           4      False
# 68       105       55     90           1      False
# 392       75       60     75           3      False
# 393      115       60    115           3      False
# ..       ...      ...    ...         ...        ...
# 632      120       60    105           5      False
# 631       80       40     65           5      False
# 46        30       40     55           1      False
# 695       65       70     58           5      False
# 794       81       95     95           6       True
#
# [800 rows x 12 columns]

# %%
# Sorting values reverse alphabetically by name

df.sort_values('Name', ascending=False)
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 794       81       95     95           6       True
# 695       65       70     58           5      False
# 46        30       40     55           1      False
# 631       80       40     65           5      False
# 632      120       60    105           5      False
# ..       ...      ...    ...         ...        ...
# 393      115       60    115           3      False
# 392       75       60     75           3      False
# 68       105       55     90           1      False
# 511      132      105     30           4      False
# 510       92       85     60           4      False
#
# [800 rows x 12 columns]

# %%
# Sorting values reverse alphabetically by name

df.sort_values('Name', ascending=False)
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 794       81       95     95           6       True
# 695       65       70     58           5      False
# 46        30       40     55           1      False
# 631       80       40     65           5      False
# 632      120       60    105           5      False
# ..       ...      ...    ...         ...        ...
# 393      115       60    115           3      False
# 392       75       60     75           3      False
# 68       105       55     90           1      False
# 511      132      105     30           4      False
# 510       92       85     60           4      False
#
# [800 rows x 12 columns]

# %%
# Multiple sort conditions

df.sort_values(['Type 1', 'HP'], ascending=(1,0))
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# ..   ...                      ...    ...       ...  ..     ...      ...
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# 129  120                   Staryu  Water       NaN  30      45       55
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 520      116       56     95           4      False
# 698      135      105    100           5      False
# 231       40       95     85           2      False
# 232       40      105     75           2      False
# 678      100       60    145           5      False
# ..       ...      ...    ...         ...        ...
# 106       25       25     50           1      False
# 125       70       25     60           1      False
# 129       70       55     85           1      False
# 139       15       20     80           1      False
# 381       10       55     80           3      False
#
# [800 rows x 12 columns]

# %%
# Adding a new column numerical column

df['Total'] = df['Attack'] + df['Defense']

df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False     98
# 1       80     60           1      False    125
# 2      100     80           1      False    165
# 3      120     80           1      False    223
# 4       50     65           1      False     95

# %%
# Adding a new string column

df['Types'] = (df['Type 1'] + " + " + df['Type 2'])

df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total           Types
# 0       65     45           1      False     98  Grass + Poison
# 1       80     60           1      False    125  Grass + Poison
# 2      100     80           1      False    165  Grass + Poison
# 3      120     80           1      False    223  Grass + Poison
# 4       50     65           1      False     95             NaN

# %%
# Dropping a column

df = df.drop(columns=['Total'])

df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary           Types
# 0       65     45           1      False  Grass + Poison
# 1       80     60           1      False  Grass + Poison
# 2      100     80           1      False  Grass + Poison
# 3      120     80           1      False  Grass + Poison
# 4       50     65           1      False             NaN

# %%
# Creating new column for total using integer location and sum function

df['Total'] = df.iloc[:, 4:10].sum(axis=1)

df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary           Types  Total
# 0       65     45           1      False  Grass + Poison    318
# 1       80     60           1      False  Grass + Poison    405
# 2      100     80           1      False  Grass + Poison    525
# 3      120     80           1      False  Grass + Poison    625
# 4       50     65           1      False             NaN    309

# %%
# Rearranging order of columns

cols = list(df.columns.values)
df = df[cols[0:2] + [cols[12]] + cols[2:7] + [cols[-1]] + cols[7:12]]

df.head()
# Out:
#    #                   Name           Types Type 1  Type 2  HP  Attack  \
# 0  1              Bulbasaur  Grass + Poison  Grass  Poison  45      49
# 1  2                Ivysaur  Grass + Poison  Grass  Poison  60      62
# 2  3               Venusaur  Grass + Poison  Grass  Poison  80      82
# 3  3  VenusaurMega Venusaur  Grass + Poison  Grass  Poison  80     100
# 4  4             Charmander             NaN   Fire     NaN  39      52
#
#    Defense  Total  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       49    318       65       65     45           1      False
# 1       63    405       80       80     60           1      False
# 2       83    525      100      100     80           1      False
# 3      123    625      122      120     80           1      False
# 4       43    309       60       50     65           1      False

# %%
# Save to CSV

df.to_csv('modified.csv', index=False)

# %%
# Filtering based on AND condition using location

df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison')]
# Out:
#        #                   Name           Types Type 1  Type 2   HP  Attack  \
# 0      1              Bulbasaur  Grass + Poison  Grass  Poison   45      49
# 1      2                Ivysaur  Grass + Poison  Grass  Poison   60      62
# 2      3               Venusaur  Grass + Poison  Grass  Poison   80      82
# 3      3  VenusaurMega Venusaur  Grass + Poison  Grass  Poison   80     100
# 48    43                 Oddish  Grass + Poison  Grass  Poison   45      50
# 49    44                  Gloom  Grass + Poison  Grass  Poison   60      65
# 50    45              Vileplume  Grass + Poison  Grass  Poison   75      80
# 75    69             Bellsprout  Grass + Poison  Grass  Poison   50      75
# 76    70             Weepinbell  Grass + Poison  Grass  Poison   65      90
# 77    71             Victreebel  Grass + Poison  Grass  Poison   80     105
# 344  315                Roselia  Grass + Poison  Grass  Poison   50      60
# 451  406                  Budew  Grass + Poison  Grass  Poison   40      30
# 452  407               Roserade  Grass + Poison  Grass  Poison   60      70
# 651  590                Foongus  Grass + Poison  Grass  Poison   69      55
# 652  591              Amoonguss  Grass + Poison  Grass  Poison  114      85
#
#      Defense  Total  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         49    318       65       65     45           1      False
# 1         63    405       80       80     60           1      False
# 2         83    525      100      100     80           1      False
# 3        123    625      122      120     80           1      False
# 48        55    320       75       65     30           1      False
# 49        70    395       85       75     40           1      False
# 50        85    490      110       90     50           1      False
# 75        35    300       70       30     40           1      False
# 76        50    390       85       45     55           1      False
# 77        65    490      100       70     70           1      False
# 344       45    400      100       80     65           3      False
# 451       35    280       50       70     55           4      False
# 452       65    515      125      105     90           4      False
# 651       45    294       55       55     15           5      False
# 652       70    464       85       80     30           5      False

# %%
# Filtering based on AND condition from two columns using locator and then sorting by HP value high to low

df.loc[(df['Type 1'] == 'Fire') & (df['HP'] >= 70)].sort_values('HP', ascending = False)
# Out:
#        #                       Name            Types Type 1    Type 2   HP  \
# 263  244                      Entei              NaN   Fire       NaN  115
# 559  500                     Emboar  Fire + Fighting   Fire  Fighting  110
# 270  250                      Ho-oh    Fire + Flying   Fire    Flying  106
# 616  555         DarmanitanZen Mode   Fire + Psychic   Fire   Psychic  105
# 615  555    DarmanitanStandard Mode              NaN   Fire       NaN  105
# 542  485                    Heatran     Fire + Steel   Fire     Steel   91
# 64    59                   Arcanine              NaN   Fire       NaN   90
# 158  146                    Moltres    Fire + Flying   Fire    Flying   90
# 558  499                    Pignite  Fire + Fighting   Fire  Fighting   90
# 736  668                     Pyroar    Fire + Normal   Fire    Normal   86
# 692  631                    Heatmor              NaN   Fire       NaN   85
# 799  721                  Volcanion     Fire + Water   Fire     Water   80
# 278  257                   Blaziken  Fire + Fighting   Fire  Fighting   80
# 279  257      BlazikenMega Blaziken  Fire + Fighting   Fire  Fighting   80
# 731  663                 Talonflame    Fire + Flying   Fire    Flying   78
# 6      6                  Charizard    Fire + Flying   Fire    Flying   78
# 7      6  CharizardMega Charizard X    Fire + Dragon   Fire    Dragon   78
# 171  157                 Typhlosion              NaN   Fire       NaN   78
# 8      6  CharizardMega Charizard Y    Fire + Flying   Fire    Flying   78
# 437  392                  Infernape  Fire + Fighting   Fire  Fighting   76
# 518  467                  Magmortar              NaN   Fire       NaN   75
# 573  514                   Simisear              NaN   Fire       NaN   75
# 723  655                    Delphox   Fire + Psychic   Fire   Psychic   75
# 43    38                  Ninetales              NaN   Fire       NaN   73
# 355  324                    Torkoal              NaN   Fire       NaN   70
# 614  554                   Darumaka              NaN   Fire       NaN   70
# 354  323      CameruptMega Camerupt    Fire + Ground   Fire    Ground   70
# 353  323                   Camerupt    Fire + Ground   Fire    Ground   70
#
#      Attack  Defense  Total  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 263     115       85    580       90       75    100           2       True
# 559     123       65    528      100       65     65           5      False
# 270     130       90    680      110      154     90           2       True
# 616      30      105    540      140      105     55           5      False
# 615     140       55    480       30       55     95           5      False
# 542      90      106    600      130      106     77           4       True
# 64      110       80    555      100       80     95           1      False
# 158     100       90    580      125       85     90           1       True
# 558      93       55    418       70       55     55           5      False
# 736      68       72    507      109       66    106           6      False
# 692      97       66    484      105       66     65           5      False
# 799     110      120    600      130       90     70           6       True
# 278     120       70    530      110       70     80           3      False
# 279     160       80    630      130       80    100           3      False
# 731      81       71    499       74       69    126           6      False
# 6        84       78    534      109       85    100           1      False
# 7       130      111    634      130       85    100           1      False
# 171      84       78    534      109       85    100           2      False
# 8       104       78    634      159      115    100           1      False
# 437     104       71    534      104       71    108           4      False
# 518      95       67    540      125       95     83           4      False
# 573      98       63    498       98       63    101           5      False
# 723      69       72    534      114      100    104           6      False
# 43       76       75    505       81      100    100           1      False
# 355      85      140    470       85       70     20           3      False
# 614      90       45    315       15       45     50           5      False
# 354     120      100    560      145      105     20           3      False
# 353     100       70    460      105       75     40           3      False

# %%
# Showing all records that contain part of a word or name

df.loc[df['Name'].str.contains('Mega')]
# Out:
#        #                       Name               Types    Type 1    Type 2  \
# 3      3      VenusaurMega Venusaur      Grass + Poison     Grass    Poison
# 7      6  CharizardMega Charizard X       Fire + Dragon      Fire    Dragon
# 8      6  CharizardMega Charizard Y       Fire + Flying      Fire    Flying
# 12     9    BlastoiseMega Blastoise                 NaN     Water       NaN
# 19    15      BeedrillMega Beedrill        Bug + Poison       Bug    Poison
# 23    18        PidgeotMega Pidgeot     Normal + Flying    Normal    Flying
# 71    65      AlakazamMega Alakazam                 NaN   Psychic       NaN
# 87    80        SlowbroMega Slowbro     Water + Psychic     Water   Psychic
# 102   94          GengarMega Gengar      Ghost + Poison     Ghost    Poison
# 124  115  KangaskhanMega Kangaskhan                 NaN    Normal       NaN
# 137  127          PinsirMega Pinsir        Bug + Flying       Bug    Flying
# 141  130      GyaradosMega Gyarados        Water + Dark     Water      Dark
# 154  142  AerodactylMega Aerodactyl       Rock + Flying      Rock    Flying
# 163  150        MewtwoMega Mewtwo X  Psychic + Fighting   Psychic  Fighting
# 164  150        MewtwoMega Mewtwo Y                 NaN   Psychic       NaN
# 168  154                   Meganium                 NaN     Grass       NaN
# 196  181      AmpharosMega Ampharos   Electric + Dragon  Electric    Dragon
# 224  208        SteelixMega Steelix      Steel + Ground     Steel    Ground
# 229  212          ScizorMega Scizor         Bug + Steel       Bug     Steel
# 232  214    HeracrossMega Heracross      Bug + Fighting       Bug  Fighting
# 248  229      HoundoomMega Houndoom         Dark + Fire      Dark      Fire
# 268  248    TyranitarMega Tyranitar         Rock + Dark      Rock      Dark
# 275  254      SceptileMega Sceptile      Grass + Dragon     Grass    Dragon
# 279  257      BlazikenMega Blaziken     Fire + Fighting      Fire  Fighting
# 283  260      SwampertMega Swampert      Water + Ground     Water    Ground
# 306  282    GardevoirMega Gardevoir     Psychic + Fairy   Psychic     Fairy
# 327  302        SableyeMega Sableye        Dark + Ghost      Dark     Ghost
# 329  303          MawileMega Mawile       Steel + Fairy     Steel     Fairy
# 333  306          AggronMega Aggron                 NaN     Steel       NaN
# 336  308      MedichamMega Medicham  Fighting + Psychic  Fighting   Psychic
# 339  310    ManectricMega Manectric                 NaN  Electric       NaN
# 349  319      SharpedoMega Sharpedo        Water + Dark     Water      Dark
# 354  323      CameruptMega Camerupt       Fire + Ground      Fire    Ground
# 366  334        AltariaMega Altaria      Dragon + Fairy    Dragon     Fairy
# 387  354        BanetteMega Banette                 NaN     Ghost       NaN
# 393  359            AbsolMega Absol                 NaN      Dark       NaN
# 397  362          GlalieMega Glalie                 NaN       Ice       NaN
# 409  373    SalamenceMega Salamence     Dragon + Flying    Dragon    Flying
# 413  376    MetagrossMega Metagross     Steel + Psychic     Steel   Psychic
# 418  380          LatiasMega Latias    Dragon + Psychic    Dragon   Psychic
# 420  381          LatiosMega Latios    Dragon + Psychic    Dragon   Psychic
# 426  384      RayquazaMega Rayquaza     Dragon + Flying    Dragon    Flying
# 476  428        LopunnyMega Lopunny   Normal + Fighting    Normal  Fighting
# 494  445      GarchompMega Garchomp     Dragon + Ground    Dragon    Ground
# 498  448        LucarioMega Lucario    Fighting + Steel  Fighting     Steel
# 511  460    AbomasnowMega Abomasnow         Grass + Ice     Grass       Ice
# 527  475        GalladeMega Gallade  Psychic + Fighting   Psychic  Fighting
# 591  531          AudinoMega Audino      Normal + Fairy    Normal     Fairy
# 796  719        DiancieMega Diancie        Rock + Fairy      Rock     Fairy
#
#       HP  Attack  Defense  Total  Sp. Atk  Sp. Def  Speed  Generation  \
# 3     80     100      123    625      122      120     80           1
# 7     78     130      111    634      130       85    100           1
# 8     78     104       78    634      159      115    100           1
# 12    79     103      120    630      135      115     78           1
# 19    65     150       40    495       15       80    145           1
# 23    83      80       80    579      135       80    121           1
# 71    55      50       65    590      175       95    150           1
# 87    95      75      180    590      130       80     30           1
# 102   60      65       80    600      170       95    130           1
# 124  105     125      100    590       60      100    100           1
# 137   65     155      120    600       65       90    105           1
# 141   95     155      109    640       70      130     81           1
# 154   80     135       85    615       70       95    150           1
# 163  106     190      100    780      154      100    130           1
# 164  106     150       70    780      194      120    140           1
# 168   80      82      100    525       83      100     80           2
# 196   90      95      105    610      165      110     45           2
# 224   75     125      230    610       55       95     30           2
# 229   70     150      140    600       65      100     75           2
# 232   80     185      115    600       40      105     75           2
# 248   75      90       90    600      140       90    115           2
# 268  100     164      150    700       95      120     71           2
# 275   70     110       75    630      145       85    145           3
# 279   80     160       80    630      130       80    100           3
# 283  100     150      110    635       95      110     70           3
# 306   68      85       65    618      165      135    100           3
# 327   50      85      125    480       85      115     20           3
# 329   50     105      125    480       55       95     50           3
# 333   70     140      230    630       60       80     50           3
# 336   60     100       85    510       80       85    100           3
# 339   70      75       80    575      135       80    135           3
# 349   70     140       70    560      110       65    105           3
# 354   70     120      100    560      145      105     20           3
# 366   75     110      110    590      110      105     80           3
# 387   64     165       75    555       93       83     75           3
# 393   65     150       60    565      115       60    115           3
# 397   80     120       80    580      120       80    100           3
# 409   95     145      130    700      120       90    120           3
# 413   80     145      150    700      105      110    110           3
# 418   80     100      120    700      140      150    110           3
# 420   80     130      100    700      160      120    110           3
# 426  105     180      100    780      180      100    115           3
# 476   65     136       94    580       54       96    135           4
# 494  108     170      115    700      120       95     92           4
# 498   70     145       88    625      140       70    112           4
# 511   90     132      105    594      132      105     30           4
# 527   68     165       95    618       65      115    110           4
# 591  103      60      126    545       80      126     50           5
# 796   50     160      110    700      160      110    110           6
#
#      Legendary
# 3        False
# 7        False
# 8        False
# 12       False
# 19       False
# 23       False
# 71       False
# 87       False
# 102      False
# 124      False
# 137      False
# 141      False
# 154      False
# 163       True
# 164       True
# 168      False
# 196      False
# 224      False
# 229      False
# 232      False
# 248      False
# 268      False
# 275      False
# 279      False
# 283      False
# 306      False
# 327      False
# 329      False
# 333      False
# 336      False
# 339      False
# 349      False
# 354      False
# 366      False
# 387      False
# 393      False
# 397      False
# 409      False
# 413      False
# 418       True
# 420       True
# 426       True
# 476      False
# 494      False
# 498      False
# 511      False
# 527      False
# 591      False
# 796       True

# %%
# Showing all records that don't contain part of a word or name

df.loc[~df['Name'].str.contains('Mega')]
# Out:
#        #                 Name            Types   Type 1  Type 2   HP  Attack  \
# 0      1            Bulbasaur   Grass + Poison    Grass  Poison   45      49
# 1      2              Ivysaur   Grass + Poison    Grass  Poison   60      62
# 2      3             Venusaur   Grass + Poison    Grass  Poison   80      82
# 4      4           Charmander              NaN     Fire     NaN   39      52
# 5      5           Charmeleon              NaN     Fire     NaN   58      64
# ..   ...                  ...              ...      ...     ...  ...     ...
# 794  718     Zygarde50% Forme  Dragon + Ground   Dragon  Ground  108     100
# 795  719              Diancie     Rock + Fairy     Rock   Fairy   50     100
# 797  720  HoopaHoopa Confined  Psychic + Ghost  Psychic   Ghost   80     110
# 798  720   HoopaHoopa Unbound   Psychic + Dark  Psychic    Dark   80     160
# 799  721            Volcanion     Fire + Water     Fire   Water   80     110
#
#      Defense  Total  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         49    318       65       65     45           1      False
# 1         63    405       80       80     60           1      False
# 2         83    525      100      100     80           1      False
# 4         43    309       60       50     65           1      False
# 5         58    405       80       65     80           1      False
# ..       ...    ...      ...      ...    ...         ...        ...
# 794      121    600       81       95     95           6       True
# 795      150    600      100      150     50           6       True
# 797       60    600      150      130     70           6       True
# 798       60    680      170      130     80           6       True
# 799      120    600      130       90     70           6       True
#
# [751 rows x 14 columns]

# %%
# Filtering out using string contains and an or operator. Note: flags = re.I ignores case!

df.loc[df['Type 1'].str.contains('fire|grass', flags = re.I)]
# Out:
#        #                   Name           Types Type 1  Type 2   HP  Attack  \
# 0      1              Bulbasaur  Grass + Poison  Grass  Poison   45      49
# 1      2                Ivysaur  Grass + Poison  Grass  Poison   60      62
# 2      3               Venusaur  Grass + Poison  Grass  Poison   80      82
# 3      3  VenusaurMega Venusaur  Grass + Poison  Grass  Poison   80     100
# 4      4             Charmander             NaN   Fire     NaN   39      52
# ..   ...                    ...             ...    ...     ...  ...     ...
# 735  667                 Litleo   Fire + Normal   Fire  Normal   62      50
# 736  668                 Pyroar   Fire + Normal   Fire  Normal   86      68
# 740  672                 Skiddo             NaN  Grass     NaN   66      65
# 741  673                 Gogoat             NaN  Grass     NaN  123     100
# 799  721              Volcanion    Fire + Water   Fire   Water   80     110
#
#      Defense  Total  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         49    318       65       65     45           1      False
# 1         63    405       80       80     60           1      False
# 2         83    525      100      100     80           1      False
# 3        123    625      122      120     80           1      False
# 4         43    309       60       50     65           1      False
# ..       ...    ...      ...      ...    ...         ...        ...
# 735       58    369       73       54     72           6      False
# 736       72    507      109       66    106           6      False
# 740       48    350       62       57     52           6      False
# 741       62    531       97       81     68           6      False
# 799      120    600      130       90     70           6       True
#
# [122 rows x 14 columns]

# %%
# Finding all names that start with "pi" (^ indicates starts with) in them with string contains

df.loc[df['Name'].str.contains('^pi[a-z]', flags = re.I)]
# Out:
#        #                 Name            Types    Type 1    Type 2   HP  \
# 20    16               Pidgey  Normal + Flying    Normal    Flying   40
# 21    17            Pidgeotto  Normal + Flying    Normal    Flying   63
# 22    18              Pidgeot  Normal + Flying    Normal    Flying   83
# 23    18  PidgeotMega Pidgeot  Normal + Flying    Normal    Flying   83
# 30    25              Pikachu              NaN  Electric       NaN   35
# 136  127               Pinsir              NaN       Bug       NaN   65
# 137  127    PinsirMega Pinsir     Bug + Flying       Bug    Flying   65
# 186  172                Pichu              NaN  Electric       NaN   20
# 219  204               Pineco              NaN       Bug       NaN   50
# 239  221            Piloswine     Ice + Ground       Ice    Ground  100
# 438  393               Piplup              NaN     Water       NaN   53
# 558  499              Pignite  Fire + Fighting      Fire  Fighting   90
# 578  519               Pidove  Normal + Flying    Normal    Flying   50
#
#      Attack  Defense  Total  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 20       45       40    251       35       35     56           1      False
# 21       60       55    349       50       50     71           1      False
# 22       80       75    479       70       70    101           1      False
# 23       80       80    579      135       80    121           1      False
# 30       55       40    320       50       50     90           1      False
# 136     125      100    500       55       70     85           1      False
# 137     155      120    600       65       90    105           1      False
# 186      40       15    205       35       35     60           2      False
# 219      65       90    290       35       35     15           2      False
# 239     100       80    450       60       60     50           2      False
# 438      51       53    314       61       56     40           4      False
# 558      93       55    418       70       55     55           5      False
# 578      55       50    264       36       30     43           5      False

# %%
# Getting all names that end with "saur"

df.loc[df['Name'].str.contains('[a-z]saur', flags = re.I)]
# Out:
#    #                   Name           Types Type 1  Type 2  HP  Attack  \
# 0  1              Bulbasaur  Grass + Poison  Grass  Poison  45      49
# 1  2                Ivysaur  Grass + Poison  Grass  Poison  60      62
# 2  3               Venusaur  Grass + Poison  Grass  Poison  80      82
# 3  3  VenusaurMega Venusaur  Grass + Poison  Grass  Poison  80     100
#
#    Defense  Total  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       49    318       65       65     45           1      False
# 1       63    405       80       80     60           1      False
# 2       83    525      100      100     80           1      False
# 3      123    625      122      120     80           1      False

# %%
# Conditional change

df.loc[df['Type 1'] == 'Fire', 'Type 1'] = 'Flame'

df.loc[df['Type 1']  == 'Flame']
# Out:
#        #                       Name            Types Type 1    Type 2   HP  \
# 4      4                 Charmander              NaN  Flame       NaN   39
# 5      5                 Charmeleon              NaN  Flame       NaN   58
# 6      6                  Charizard    Fire + Flying  Flame    Flying   78
# 7      6  CharizardMega Charizard X    Fire + Dragon  Flame    Dragon   78
# 8      6  CharizardMega Charizard Y    Fire + Flying  Flame    Flying   78
# 42    37                     Vulpix              NaN  Flame       NaN   38
# 43    38                  Ninetales              NaN  Flame       NaN   73
# 63    58                  Growlithe              NaN  Flame       NaN   55
# 64    59                   Arcanine              NaN  Flame       NaN   90
# 83    77                     Ponyta              NaN  Flame       NaN   50
# 84    78                   Rapidash              NaN  Flame       NaN   65
# 135  126                     Magmar              NaN  Flame       NaN   65
# 147  136                    Flareon              NaN  Flame       NaN   65
# 158  146                    Moltres    Fire + Flying  Flame    Flying   90
# 169  155                  Cyndaquil              NaN  Flame       NaN   39
# 170  156                    Quilava              NaN  Flame       NaN   58
# 171  157                 Typhlosion              NaN  Flame       NaN   78
# 236  218                     Slugma              NaN  Flame       NaN   40
# 237  219                   Magcargo      Fire + Rock  Flame      Rock   50
# 259  240                      Magby              NaN  Flame       NaN   45
# 263  244                      Entei              NaN  Flame       NaN  115
# 270  250                      Ho-oh    Fire + Flying  Flame    Flying  106
# 276  255                    Torchic              NaN  Flame       NaN   45
# 277  256                  Combusken  Fire + Fighting  Flame  Fighting   60
# 278  257                   Blaziken  Fire + Fighting  Flame  Fighting   80
# 279  257      BlazikenMega Blaziken  Fire + Fighting  Flame  Fighting   80
# 352  322                      Numel    Fire + Ground  Flame    Ground   60
# 353  323                   Camerupt    Fire + Ground  Flame    Ground   70
# 354  323      CameruptMega Camerupt    Fire + Ground  Flame    Ground   70
# 355  324                    Torkoal              NaN  Flame       NaN   70
# 435  390                   Chimchar              NaN  Flame       NaN   44
# 436  391                   Monferno  Fire + Fighting  Flame  Fighting   64
# 437  392                  Infernape  Fire + Fighting  Flame  Fighting   76
# 518  467                  Magmortar              NaN  Flame       NaN   75
# 542  485                    Heatran     Fire + Steel  Flame     Steel   91
# 557  498                      Tepig              NaN  Flame       NaN   65
# 558  499                    Pignite  Fire + Fighting  Flame  Fighting   90
# 559  500                     Emboar  Fire + Fighting  Flame  Fighting  110
# 572  513                    Pansear              NaN  Flame       NaN   50
# 573  514                   Simisear              NaN  Flame       NaN   75
# 614  554                   Darumaka              NaN  Flame       NaN   70
# 615  555    DarmanitanStandard Mode              NaN  Flame       NaN  105
# 616  555         DarmanitanZen Mode   Fire + Psychic  Flame   Psychic  105
# 692  631                    Heatmor              NaN  Flame       NaN   85
# 721  653                   Fennekin              NaN  Flame       NaN   40
# 722  654                    Braixen              NaN  Flame       NaN   59
# 723  655                    Delphox   Fire + Psychic  Flame   Psychic   75
# 730  662                Fletchinder    Fire + Flying  Flame    Flying   62
# 731  663                 Talonflame    Fire + Flying  Flame    Flying   78
# 735  667                     Litleo    Fire + Normal  Flame    Normal   62
# 736  668                     Pyroar    Fire + Normal  Flame    Normal   86
# 799  721                  Volcanion     Fire + Water  Flame     Water   80
#
#      Attack  Defense  Total  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 4        52       43    309       60       50     65           1      False
# 5        64       58    405       80       65     80           1      False
# 6        84       78    534      109       85    100           1      False
# 7       130      111    634      130       85    100           1      False
# 8       104       78    634      159      115    100           1      False
# 42       41       40    299       50       65     65           1      False
# 43       76       75    505       81      100    100           1      False
# 63       70       45    350       70       50     60           1      False
# 64      110       80    555      100       80     95           1      False
# 83       85       55    410       65       65     90           1      False
# 84      100       70    500       80       80    105           1      False
# 135      95       57    495      100       85     93           1      False
# 147     130       60    525       95      110     65           1      False
# 158     100       90    580      125       85     90           1       True
# 169      52       43    309       60       50     65           2      False
# 170      64       58    405       80       65     80           2      False
# 171      84       78    534      109       85    100           2      False
# 236      40       40    250       70       40     20           2      False
# 237      50      120    410       80       80     30           2      False
# 259      75       37    365       70       55     83           2      False
# 263     115       85    580       90       75    100           2       True
# 270     130       90    680      110      154     90           2       True
# 276      60       40    310       70       50     45           3      False
# 277      85       60    405       85       60     55           3      False
# 278     120       70    530      110       70     80           3      False
# 279     160       80    630      130       80    100           3      False
# 352      60       40    305       65       45     35           3      False
# 353     100       70    460      105       75     40           3      False
# 354     120      100    560      145      105     20           3      False
# 355      85      140    470       85       70     20           3      False
# 435      58       44    309       58       44     61           4      False
# 436      78       52    405       78       52     81           4      False
# 437     104       71    534      104       71    108           4      False
# 518      95       67    540      125       95     83           4      False
# 542      90      106    600      130      106     77           4       True
# 557      63       45    308       45       45     45           5      False
# 558      93       55    418       70       55     55           5      False
# 559     123       65    528      100       65     65           5      False
# 572      53       48    316       53       48     64           5      False
# 573      98       63    498       98       63    101           5      False
# 614      90       45    315       15       45     50           5      False
# 615     140       55    480       30       55     95           5      False
# 616      30      105    540      140      105     55           5      False
# 692      97       66    484      105       66     65           5      False
# 721      45       40    307       62       60     60           6      False
# 722      59       58    409       90       70     73           6      False
# 723      69       72    534      114      100    104           6      False
# 730      73       55    382       56       52     84           6      False
# 731      81       71    499       74       69    126           6      False
# 735      50       58    369       73       54     72           6      False
# 736      68       72    507      109       66    106           6      False
# 799     110      120    600      130       90     70           6       True

# %%
# Changing back because...it's just wrong to rename the types

df.loc[df['Type 1'] == 'Flame', 'Type 1'] = 'Fire'

df.loc[df['Type 1']  == 'Fire']
# Out:
#        #                       Name            Types Type 1    Type 2   HP  \
# 4      4                 Charmander              NaN   Fire       NaN   39
# 5      5                 Charmeleon              NaN   Fire       NaN   58
# 6      6                  Charizard    Fire + Flying   Fire    Flying   78
# 7      6  CharizardMega Charizard X    Fire + Dragon   Fire    Dragon   78
# 8      6  CharizardMega Charizard Y    Fire + Flying   Fire    Flying   78
# 42    37                     Vulpix              NaN   Fire       NaN   38
# 43    38                  Ninetales              NaN   Fire       NaN   73
# 63    58                  Growlithe              NaN   Fire       NaN   55
# 64    59                   Arcanine              NaN   Fire       NaN   90
# 83    77                     Ponyta              NaN   Fire       NaN   50
# 84    78                   Rapidash              NaN   Fire       NaN   65
# 135  126                     Magmar              NaN   Fire       NaN   65
# 147  136                    Flareon              NaN   Fire       NaN   65
# 158  146                    Moltres    Fire + Flying   Fire    Flying   90
# 169  155                  Cyndaquil              NaN   Fire       NaN   39
# 170  156                    Quilava              NaN   Fire       NaN   58
# 171  157                 Typhlosion              NaN   Fire       NaN   78
# 236  218                     Slugma              NaN   Fire       NaN   40
# 237  219                   Magcargo      Fire + Rock   Fire      Rock   50
# 259  240                      Magby              NaN   Fire       NaN   45
# 263  244                      Entei              NaN   Fire       NaN  115
# 270  250                      Ho-oh    Fire + Flying   Fire    Flying  106
# 276  255                    Torchic              NaN   Fire       NaN   45
# 277  256                  Combusken  Fire + Fighting   Fire  Fighting   60
# 278  257                   Blaziken  Fire + Fighting   Fire  Fighting   80
# 279  257      BlazikenMega Blaziken  Fire + Fighting   Fire  Fighting   80
# 352  322                      Numel    Fire + Ground   Fire    Ground   60
# 353  323                   Camerupt    Fire + Ground   Fire    Ground   70
# 354  323      CameruptMega Camerupt    Fire + Ground   Fire    Ground   70
# 355  324                    Torkoal              NaN   Fire       NaN   70
# 435  390                   Chimchar              NaN   Fire       NaN   44
# 436  391                   Monferno  Fire + Fighting   Fire  Fighting   64
# 437  392                  Infernape  Fire + Fighting   Fire  Fighting   76
# 518  467                  Magmortar              NaN   Fire       NaN   75
# 542  485                    Heatran     Fire + Steel   Fire     Steel   91
# 557  498                      Tepig              NaN   Fire       NaN   65
# 558  499                    Pignite  Fire + Fighting   Fire  Fighting   90
# 559  500                     Emboar  Fire + Fighting   Fire  Fighting  110
# 572  513                    Pansear              NaN   Fire       NaN   50
# 573  514                   Simisear              NaN   Fire       NaN   75
# 614  554                   Darumaka              NaN   Fire       NaN   70
# 615  555    DarmanitanStandard Mode              NaN   Fire       NaN  105
# 616  555         DarmanitanZen Mode   Fire + Psychic   Fire   Psychic  105
# 692  631                    Heatmor              NaN   Fire       NaN   85
# 721  653                   Fennekin              NaN   Fire       NaN   40
# 722  654                    Braixen              NaN   Fire       NaN   59
# 723  655                    Delphox   Fire + Psychic   Fire   Psychic   75
# 730  662                Fletchinder    Fire + Flying   Fire    Flying   62
# 731  663                 Talonflame    Fire + Flying   Fire    Flying   78
# 735  667                     Litleo    Fire + Normal   Fire    Normal   62
# 736  668                     Pyroar    Fire + Normal   Fire    Normal   86
# 799  721                  Volcanion     Fire + Water   Fire     Water   80
#
#      Attack  Defense  Total  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 4        52       43    309       60       50     65           1      False
# 5        64       58    405       80       65     80           1      False
# 6        84       78    534      109       85    100           1      False
# 7       130      111    634      130       85    100           1      False
# 8       104       78    634      159      115    100           1      False
# 42       41       40    299       50       65     65           1      False
# 43       76       75    505       81      100    100           1      False
# 63       70       45    350       70       50     60           1      False
# 64      110       80    555      100       80     95           1      False
# 83       85       55    410       65       65     90           1      False
# 84      100       70    500       80       80    105           1      False
# 135      95       57    495      100       85     93           1      False
# 147     130       60    525       95      110     65           1      False
# 158     100       90    580      125       85     90           1       True
# 169      52       43    309       60       50     65           2      False
# 170      64       58    405       80       65     80           2      False
# 171      84       78    534      109       85    100           2      False
# 236      40       40    250       70       40     20           2      False
# 237      50      120    410       80       80     30           2      False
# 259      75       37    365       70       55     83           2      False
# 263     115       85    580       90       75    100           2       True
# 270     130       90    680      110      154     90           2       True
# 276      60       40    310       70       50     45           3      False
# 277      85       60    405       85       60     55           3      False
# 278     120       70    530      110       70     80           3      False
# 279     160       80    630      130       80    100           3      False
# 352      60       40    305       65       45     35           3      False
# 353     100       70    460      105       75     40           3      False
# 354     120      100    560      145      105     20           3      False
# 355      85      140    470       85       70     20           3      False
# 435      58       44    309       58       44     61           4      False
# 436      78       52    405       78       52     81           4      False
# 437     104       71    534      104       71    108           4      False
# 518      95       67    540      125       95     83           4      False
# 542      90      106    600      130      106     77           4       True
# 557      63       45    308       45       45     45           5      False
# 558      93       55    418       70       55     55           5      False
# 559     123       65    528      100       65     65           5      False
# 572      53       48    316       53       48     64           5      False
# 573      98       63    498       98       63    101           5      False
# 614      90       45    315       15       45     50           5      False
# 615     140       55    480       30       55     95           5      False
# 616      30      105    540      140      105     55           5      False
# 692      97       66    484      105       66     65           5      False
# 721      45       40    307       62       60     60           6      False
# 722      59       58    409       90       70     73           6      False
# 723      69       72    534      114      100    104           6      False
# 730      73       55    382       56       52     84           6      False
# 731      81       71    499       74       69    126           6      False
# 735      50       58    369       73       54     72           6      False
# 736      68       72    507      109       66    106           6      False
# 799     110      120    600      130       90     70           6       True

# %%
# Asserting Pikachu's rightful status as a legendary Pokemon

df.loc[df['Name'] == 'Pikachu', 'Legendary'] = True

df.loc[df['Name'] == 'Pikachu']
# Out:
#      #     Name Types    Type 1 Type 2  HP  Attack  Defense  Total  Sp. Atk  \
# 30  25  Pikachu   NaN  Electric    NaN  35      55       40    320       50
#
#     Sp. Def  Speed  Generation  Legendary
# 30       50     90           1       True

# %%
# Group by for aggregate stats, like type with highest average attack

df.groupby(['Type 1']).mean('HP').sort_values('Attack', ascending = False)
# Out:
#                    #         HP      Attack     Defense       Total  \
# Type 1
# Dragon    474.375000  83.312500  112.125000   86.375000  550.531250
# Fighting  363.851852  69.851852   96.777778   65.925926  416.444444
# Ground    356.281250  73.781250   95.750000   84.843750  437.500000
# Rock      392.727273  65.363636   92.863636  100.795455  453.750000
# Steel     442.851852  65.222222   92.703704  126.370370  487.703704
# Dark      461.354839  66.806452   88.387097   70.225806  445.741935
# Fire      327.403846  69.903846   84.769231   67.769231  458.076923
# Flying    677.750000  70.750000   78.750000   66.250000  485.000000
# Poison    251.785714  67.250000   74.678571   68.821429  399.142857
# Water     303.089286  72.062500   74.151786   72.946429  430.455357
# Ghost     486.500000  64.437500   73.781250   81.187500  439.562500
# Normal    319.173469  77.275510   73.469388   59.846939  401.683673
# Grass     344.871429  67.271429   73.214286   70.800000  421.142857
# Ice       423.541667  72.000000   72.750000   71.416667  433.458333
# Psychic   380.807018  70.631579   71.456140   67.684211  475.947368
# Bug       334.492754  56.884058   70.971014   70.724638  378.927536
# Electric  363.500000  59.795455   69.090909   66.295455  443.409091
# Fairy     449.529412  74.117647   61.529412   65.705882  413.176471
#
#             Sp. Atk    Sp. Def       Speed  Generation  Legendary
# Type 1
# Dragon    96.843750  88.843750   83.031250    3.875000   0.375000
# Fighting  53.111111  64.703704   66.074074    3.370370   0.000000
# Ground    56.468750  62.750000   63.906250    3.156250   0.125000
# Rock      63.340909  75.477273   55.909091    3.454545   0.090909
# Steel     67.518519  80.629630   55.259259    3.851852   0.148148
# Dark      74.645161  69.516129   76.161290    4.032258   0.064516
# Fire      88.980769  72.211538   74.442308    3.211538   0.096154
# Flying    94.250000  72.500000  102.500000    5.500000   0.500000
# Poison    60.428571  64.392857   63.571429    2.535714   0.000000
# Water     74.812500  70.517857   65.964286    2.857143   0.035714
# Ghost     79.343750  76.468750   64.343750    4.187500   0.062500
# Normal    55.816327  63.724490   71.551020    3.051020   0.020408
# Grass     77.500000  70.428571   61.928571    3.357143   0.042857
# Ice       77.541667  76.291667   63.458333    3.541667   0.083333
# Psychic   98.403509  86.280702   81.491228    3.385965   0.245614
# Bug       53.869565  64.797101   61.681159    3.217391   0.000000
# Electric  90.022727  73.704545   84.500000    3.272727   0.113636
# Fairy     78.529412  84.705882   48.588235    4.117647   0.058824

# %%
# How many of each type of Pokemon there are in our data

df.groupby(['Type 1']).count().sort_values('Name', ascending = False)
# Out:
#             #  Name  Types  Type 2   HP  Attack  Defense  Total  Sp. Atk  \
# Type 1
# Water     112   112     53      53  112     112      112    112      112
# Normal     98    98     37      37   98      98       98     98       98
# Grass      70    70     37      37   70      70       70     70       70
# Bug        69    69     52      52   69      69       69     69       69
# Psychic    57    57     19      19   57      57       57     57       57
# Fire       52    52     24      24   52      52       52     52       52
# Electric   44    44     17      17   44      44       44     44       44
# Rock       44    44     35      35   44      44       44     44       44
# Ghost      32    32     22      22   32      32       32     32       32
# Ground     32    32     19      19   32      32       32     32       32
# Dragon     32    32     21      21   32      32       32     32       32
# Dark       31    31     21      21   31      31       31     31       31
# Poison     28    28     13      13   28      28       28     28       28
# Fighting   27    27      7       7   27      27       27     27       27
# Steel      27    27     22      22   27      27       27     27       27
# Ice        24    24     11      11   24      24       24     24       24
# Fairy      17    17      2       2   17      17       17     17       17
# Flying      4     4      2       2    4       4        4      4        4
#
#           Sp. Def  Speed  Generation  Legendary
# Type 1
# Water         112    112         112        112
# Normal         98     98          98         98
# Grass          70     70          70         70
# Bug            69     69          69         69
# Psychic        57     57          57         57
# Fire           52     52          52         52
# Electric       44     44          44         44
# Rock           44     44          44         44
# Ghost          32     32          32         32
# Ground         32     32          32         32
# Dragon         32     32          32         32
# Dark           31     31          31         31
# Poison         28     28          28         28
# Fighting       27     27          27         27
# Steel          27     27          27         27
# Ice            24     24          24         24
# Fairy          17     17          17         17
# Flying          4      4           4          4
